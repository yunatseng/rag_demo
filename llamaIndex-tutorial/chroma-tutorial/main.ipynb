# %%
import chromadb

# %%
client = chromadb.PersistentClient(path="./data") # 儲存的本地資料庫位置
collection_name = "TaiwanNews" # Collection的名稱需留意不能有空格
collection = client.get_or_create_collection(name=collection_name) # 取得或建立 collection，避免報錯
